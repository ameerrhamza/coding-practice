# %% [markdown]
# # 1) Department wise attendance of students

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv('/home/amh/Program/Python/dataset/student_data_clean.csv')

df.pivot_table(index="Department", values="Attendance_Rate", columns='Gender', aggfunc="mean")
# Out:
# Gender         Female       Male      Other
# Department
# BBA         75.078125  74.194805  73.366667
# CS          76.526316  71.950000  73.315068
# EE          76.150000  76.666667  74.259259
# Math        74.316456  74.888889  75.174419
# Physics     74.985507  75.597222  74.738462
